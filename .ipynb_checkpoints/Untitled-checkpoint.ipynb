# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fe=np.linspace(-np.pi,np.pi,1000)
si=np.sin(fe)
#plt.figure(figsize=(20,6))
plt.plot(fe,si)
plt.xlabel('freq')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
from scipy.fftpack import fft,ifft
iff =fft(amp)
x=ifft(amp)
#plt.figure(figsize=(20,6))
plt.plot(fe,np.abs(x))
plt.xlabel('freq')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t =np.arange(1000)
ft=10*np.sin(14*np.pi*t/200)
plt.figure(figsize=(20,6))
plt.plot(t,ft)
plt.xlabel('freq')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
x=ifft(ft)
plt.figure(figsize=(20,6))
plt.plot(fe,np.abs(x))
plt.xlabel('freq')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')
