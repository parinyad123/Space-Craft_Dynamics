# %% [markdown]
# # Problem 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

import scipy as sp
import scipy.fftpack

import math as m
import cmath

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### 1. Sunspot Data
#
# https://vincentarelbundock.github.io/Rdatasets/datasets.html

# %%
data=pd.read_csv('sunspot.month.csv',index_col='time',parse_dates=True)
data.head()
# Out:
#             Unnamed: 0  value
# time
# 1749-01-01           1   58.0
# 1749-01-01           2   62.6
# 1749-01-01           3   70.0
# 1749-01-01           4   55.7
# 1749-01-01           5   85.0

# %%
df=data[['value']]
df
# Out:
#             value
# time
# 1749-01-01   58.0
# 1749-01-01   62.6
# 1749-01-01   70.0
# 1749-01-01   55.7
# 1749-01-01   85.0
# ...           ...
# 2013-01-01   78.7
# 2013-01-01   52.5
# 2013-05-01   57.0
# 2013-01-01   66.0
# 2013-01-01   37.0
#
# [3177 rows x 1 columns]

# %%
line=df.plot.line()

# %%
ax=df[['value']].plot(kind='line',title='sunspot',color='c',figsize=(15,8))

# %% [markdown]
# ### 2. Appoximation
# $$a_0+2\Re a _{26}\exp^{-2\pi i kt/288}$$

# %%
# Find the Fourier Coefficients using iFFT
a=sp.fftpack.ifft(data[['value']])

# Approximation using FFT
k=26
p=a[0]+2*a[26].real*m.exp(complex(0,(-2*m.pi*k*t/288)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-dce13e440543> in <module>
#       4 # Approximation using FFT
#       5 k=26
# ----> 6 p=a[0]+2*a[26].real*m.exp(complex(0,(-2*m.pi*k*t/288)))
#
# TypeError: complex() second argument must be a number, not 'DataFrame'

# %%
a[1]
# Out:
# array([62.6+0.j])

# %%
a[26].real
# Out:
# array([45.3])

# %%
m.pi
# Out:
# 3.141592653589793

# %%
import numpy as np
np.imag(1j)
# Out:
# 1.0

# %%
complex(0,2)
# Out:
# 2j

# %%
t=pd.read_csv('sunspot.month.csv')[['time']]

# %%
t
# Out:
#              time
# 0     1749.000000
# 1     1749.083333
# 2     1749.166667
# 3     1749.250000
# 4     1749.333333
# ...           ...
# 3172  2013.333333
# 3173  2013.416667
# 3174  2013.500000
# 3175  2013.583333
# 3176  2013.666667
#
# [3177 rows x 1 columns]

# %%
from numpy import genfromtxt
my_data = genfromtxt('sunspot.month.csv', delimiter=',')
my_data
# Out:
# array([[          nan,           nan,           nan],
#        [          nan, 1749.        ,   58.        ],
#        [          nan, 1749.08333333,   62.6       ],
#        ...,
#        [          nan, 2013.5       ,   57.        ],
#        [          nan, 2013.58333333,   66.        ],
#        [          nan, 2013.66666667,   37.        ]])

# %%
my_data[[1,:],1]
# Out:
#   File "<ipython-input-73-91de2685c30c>", line 1
#     my_data[[1,:],1]
#                ^
# SyntaxError: invalid syntax
